# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
pic=Image.open('C:/Users/acer/Documents/imageprocess/opencv/peakpx.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5120x2880 at 0x24C2B102278>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (2880, 5120, 3)

# %%
pic_arr
# Out:
# array([[[33, 34, 39],
#         [20, 21, 26],
#         [16, 17, 22],
#         ...,
#         [14, 13, 18],
#         [17, 16, 21],
#         [29, 28, 33]],
#
#        [[20, 21, 26],
#         [ 6,  7, 12],
#         [ 2,  3,  8],
#         ...,
#         [ 0,  0,  4],
#         [ 4,  3,  8],
#         [15, 14, 19]],
#
#        [[16, 17, 22],
#         [ 2,  3,  8],
#         [ 0,  0,  5],
#         ...,
#         [ 0,  0,  4],
#         [ 0,  0,  4],
#         [12, 11, 16]],
#
#        ...,
#
#        [[14, 17, 22],
#         [ 2,  5, 10],
#         [ 0,  2,  7],
#         ...,
#         [ 0,  0,  5],
#         [ 0,  1,  6],
#         [12, 13, 18]],
#
#        [[17, 20, 25],
#         [ 6,  9, 14],
#         [ 2,  5, 10],
#         ...,
#         [ 0,  1,  6],
#         [ 4,  5, 10],
#         [15, 16, 21]],
#
#        [[31, 34, 39],
#         [19, 22, 27],
#         [16, 19, 24],
#         ...,
#         [14, 15, 20],
#         [18, 19, 24],
#         [29, 30, 35]]], dtype=uint8)

# %%
plt.imshow(pic_arr)

# %%
pic_red=pic_arr.copy()

# %%
pic_red[:,:,1]=0

# %%
pic_red[:,:,2]=0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (2880, 5120, 3)
