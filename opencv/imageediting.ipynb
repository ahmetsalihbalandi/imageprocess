# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2
img=cv2.imread('C:/Users/acer/Documents/imageprocess/opencv/peakpx.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %% [markdown]
# Matplotlib -> RGB
# OpenCV -> BGR

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_gray=cv2.imread('C:/Users/acer/Documents/imageprocess/opencv/peakpx.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap='gray')

# %% [markdown]
# excellent choice of image for gray scale :d

# %%
plt.imshow(img_gray,cmap='magma')

# %%
cv2.imwrite('firstfixedimg.jpg',img_gray)
# Out:
# True
